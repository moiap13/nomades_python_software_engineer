# %% [markdown]
# # Fred aquisition data

# %%
import json
import matplotlib.pyplot as plt
import requests

# %%
# Load the secret api key
with open('api_cred.json', 'r') as f:
  secrets = json.load(f)

api_key = secrets['api_key'] # you can hardcode your value here if you want

# %% [markdown]
# ### Some example without Pandas

# %%
seriesID = "UNRATE"   # Unemployment rate
start = "2015-01-01"  # start date
end = "2023-10-31"    # end date
units = "pc1"         # Percent change from a year ago

url = "https://api.stlouisfed.org/fred/series/observations" + \
      f"?series_id={seriesID}&api_key={api_key}&file_type=json" + \
      f"&observation_start={start}&observation_end={end}&units={units}"

response = requests.get(url)

# print the response
print("response :", response)
# Out:
# response : <Response [200]>

# %% [markdown]
# Here the response is <Response [200]> which means that the request was successful.
# 200 is the status code for a successful request.

# %%
# print the status code
print("status code :", response.status_code)

# print the content
print("content :", response.content)
# Out:
# status code : 200
# content : b'{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","observation_start":"2015-01-01","observation_end":"2023-10-31","units":"pc1","output_type":1,"file_type":"json","order_by":"observation_date","sort_order":"asc","count":106,"offset":0,"limit":100000,"observations":[{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2015-01-01","value":"-13.63636"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2015-02-01","value":"-17.91045"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2015-03-01","value":"-19.40299"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2015-04-01","value":"-12.90323"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2015-05-01","value":"-11.11111"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2015-06-01","value":"-13.11475"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2015-07-01","value":"-16.12903"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2015-08-01","value":"-16.39344"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2015-09-01","value":"-15.25424"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2015-10-01","value":"-12.28070"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2015-11-01","value":"-12.06897"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2015-12-01","value":"-10.71429"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2016-01-01","value":"-15.78947"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2016-02-01","value":"-10.90909"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2016-03-01","value":"-7.40741"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2016-04-01","value":"-5.55556"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2016-05-01","value":"-14.28571"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2016-06-01","value":"-7.54717"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2016-07-01","value":"-7.69231"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2016-08-01","value":"-3.92157"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2016-09-01","value":"0.00000"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2016-10-01","value":"-2.00000"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2016-11-01","value":"-7.84314"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2016-12-01","value":"-6.00000"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2017-01-01","value":"-2.08333"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2017-02-01","value":"-6.12245"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2017-03-01","value":"-12.00000"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2017-04-01","value":"-13.72549"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2017-05-01","value":"-8.33333"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2017-06-01","value":"-12.24490"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2017-07-01","value":"-10.41667"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2017-08-01","value":"-10.20408"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2017-09-01","value":"-14.00000"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2017-10-01","value":"-14.28571"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2017-11-01","value":"-10.63830"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2017-12-01","value":"-12.76596"},{"realtime_start":"2023-12-21","realtime_end":"2023-12-21","date":"2018-01-01","value":"-14.89362"},{"realtime_start":"2023-12 ...

# %% [markdown]
# Here the content is in byte format.
# We can decode it to utf-8 format.
# But, as the reposnse is in json format,
# we can directly decode it to json format using the json() method from requests library

# %%
# print the json content
print("json content :", response.json())
# Out:
# json content : {'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'observation_start': '2015-01-01', 'observation_end': '2023-10-31', 'units': 'pc1', 'output_type': 1, 'file_type': 'json', 'order_by': 'observation_date', 'sort_order': 'asc', 'count': 106, 'offset': 0, 'limit': 100000, 'observations': [{'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'date': '2015-01-01', 'value': '-13.63636'}, {'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'date': '2015-02-01', 'value': '-17.91045'}, {'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'date': '2015-03-01', 'value': '-19.40299'}, {'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'date': '2015-04-01', 'value': '-12.90323'}, {'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'date': '2015-05-01', 'value': '-11.11111'}, {'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'date': '2015-06-01', 'value': '-13.11475'}, {'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'date': '2015-07-01', 'value': '-16.12903'}, {'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'date': '2015-08-01', 'value': '-16.39344'}, {'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'date': '2015-09-01', 'value': '-15.25424'}, {'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'date': '2015-10-01', 'value': '-12.28070'}, {'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'date': '2015-11-01', 'value': '-12.06897'}, {'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'date': '2015-12-01', 'value': '-10.71429'}, {'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'date': '2016-01-01', 'value': '-15.78947'}, {'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'date': '2016-02-01', 'value': '-10.90909'}, {'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'date': '2016-03-01', 'value': '-7.40741'}, {'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'date': '2016-04-01', 'value': '-5.55556'}, {'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'date': '2016-05-01', 'value': '-14.28571'}, {'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'date': '2016-06-01', 'value': '-7.54717'}, {'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'date': '2016-07-01', 'value': '-7.69231'}, {'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'date': '2016-08-01', 'value': '-3.92157'}, {'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'date': '2016-09-01', 'value': '0.00000'}, {'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'date': '2016-10-01', 'value': '-2.00000'}, {'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'date': '2016-11-01', 'value': '-7.84314'}, {'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'date': '2016-12-01', 'value': '-6.00000'}, {'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'date': '2017-01-01', 'value': '-2.08333'}, {'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'date': '2017-02-01', 'value': '-6.12245'}, {'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'date': '2017-03-01', 'value': '-12.00000'}, {'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'date': '2017-04-01', 'value': '-13.72549'}, {'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'date': '2017-05-01', 'value': '-8.33333'}, {'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'date': '2017-06-01', 'value': '-12.24490'}, {'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'date': '2017-07-01', 'value': '-10.41667'}, {'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'date': '2017-08-01', 'value': '-10.20408'}, {'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'date': '2017-09-01', 'value': '-14.00000'}, {'realtime_start': '2023-12-21', 'realtime_end': '2023-12-21', 'date': '2017-10-01', 'value': '-14.28571'}, {'realtime_start': '2023-1 ...

# %% [markdown]
# The json response contains some keys like:
#   - realtime_start
#   - realtime_end
#   - units
#   ...
#   - observations
#
# The observations key contains the data we need.
# The observation key contains a list of dictionaries. where two keys are interesting for us:
#   - date, the date of the observation
#   - value, the value of the observation

# %%
# TODO: Given the response in json format, extract a list made of tuples where the first element is the date as str type and the second element is the value as float type
# Hint: use list comprehension
# FRED API Observations DOC : https://fred.stlouisfed.org/docs/api/fred/series_observations.html


data = [(observation["date"],float(observation["value"])) for observation in response.json()["observations"]]
print("data :", data)
# Out:
# data : [('2015-01-01', -13.63636), ('2015-02-01', -17.91045), ('2015-03-01', -19.40299), ('2015-04-01', -12.90323), ('2015-05-01', -11.11111), ('2015-06-01', -13.11475), ('2015-07-01', -16.12903), ('2015-08-01', -16.39344), ('2015-09-01', -15.25424), ('2015-10-01', -12.2807), ('2015-11-01', -12.06897), ('2015-12-01', -10.71429), ('2016-01-01', -15.78947), ('2016-02-01', -10.90909), ('2016-03-01', -7.40741), ('2016-04-01', -5.55556), ('2016-05-01', -14.28571), ('2016-06-01', -7.54717), ('2016-07-01', -7.69231), ('2016-08-01', -3.92157), ('2016-09-01', 0.0), ('2016-10-01', -2.0), ('2016-11-01', -7.84314), ('2016-12-01', -6.0), ('2017-01-01', -2.08333), ('2017-02-01', -6.12245), ('2017-03-01', -12.0), ('2017-04-01', -13.72549), ('2017-05-01', -8.33333), ('2017-06-01', -12.2449), ('2017-07-01', -10.41667), ('2017-08-01', -10.20408), ('2017-09-01', -14.0), ('2017-10-01', -14.28571), ('2017-11-01', -10.6383), ('2017-12-01', -12.76596), ('2018-01-01', -14.89362), ('2018-02-01', -10.86957), ('2018-03-01', -9.09091), ('2018-04-01', -9.09091), ('2018-05-01', -13.63636), ('2018-06-01', -6.97674), ('2018-07-01', -11.62791), ('2018-08-01', -13.63636), ('2018-09-01', -13.95349), ('2018-10-01', -9.52381), ('2018-11-01', -9.52381), ('2018-12-01', -4.87805), ('2019-01-01', 0.0), ('2019-02-01', -7.31707), ('2019-03-01', -5.0), ('2019-04-01', -10.0), ('2019-05-01', -2.63158), ('2019-06-01', -10.0), ('2019-07-01', -2.63158), ('2019-08-01', -2.63158), ('2019-09-01', -5.40541), ('2019-10-01', -5.26316), ('2019-11-01', -5.26316), ('2019-12-01', -7.69231), ('2020-01-01', -12.5), ('2020-02-01', -7.89474), ('2020-03-01', 15.78947), ('2020-04-01', 308.33333), ('2020-05-01', 256.75676), ('2020-06-01', 205.55556), ('2020-07-01', 175.67568), ('2020-08-01', 127.02703), ('2020-09-01', 125.71429), ('2020-10-01', 91.66667), ('2020-11-01', 86.11111), ('2020-12-01', 86.11111), ('2021-01-01', 80.0), ('2021-02-01', 77.14286), ('2021-03-01', 38.63636), ('2021-04-01', -58.5034), ('2021-05-01', -56.06061), ('2021-06-01', -46.36364), ('2021-07-01', -47.05882), ('2021-08-01', -38.09524), ('2021-09-01', -39.24051), ('2021-10-01', -34.78261), ('2021-11-01', -37.31343), ('2021-12-01', -41.79104), ('2022-01-01', -36.50794), ('2022-02-01', -38.70968), ('2022-03-01', -40.98361), ('2022-04-01', -40.98361), ('2022-05-01', -37.93103), ('2022-06-01', -38.98305), ('2022-07-01', -35.18519), ('2022-08-01', -28.84615), ('2022-09-01', -27.08333), ('2022-10-01', -17.77778), ('2022-11-01', -14.28571), ('2022-12-01', -10.25641), ('2023-01-01', -15.0), ('2023-02-01', -5.26316), ('2023-03-01', -2.77778), ('2023-04-01', -5.55556), ('2023-05-01', 2.77778), ('2023-06-01', 0.0), ('2023-07-01', 0.0), ('2023-08-01', 2.7027), ('2023-09-01', 8.57143), ('2023-10-01', 5.40541)]

# %%
# Plotting the data
# TODO: plot the data, you need to create the same plot as the one following
plt.plot([x[0] for x in data], [y[1] for y in data], label=u"Unemployment rate")
plt.legend()
plt.xlabel("Date")
plt.ylabel("Unemployment rate")
plt.title("Unemployment rate from 2015 to 2023")
# show the x values only once per date
plt.xticks([x[0] for x in data][::12], rotation=45)
plt.show()

# %%
from example_plot import example_plot
x = [x[0] for x in data]
y = [y[1] for y in data]
example_plot(x, y, u"Unemployment rate")
# I changed the plt.xticks to display only one date per year and changed the reotation to 90degree
# Out:
# <function matplotlib.pyplot.figure(num: 'int | str | Figure | SubFigure | None' = None, figsize: 'tuple[float, float] | None' = None, dpi: 'float | None' = None, *, facecolor: 'ColorType | None' = None, edgecolor: 'ColorType | None' = None, frameon: 'bool' = True, FigureClass: 'type[Figure]' = <class 'matplotlib.figure.Figure'>, clear: 'bool' = False, **kwargs) -> 'Figure'>

# %% [markdown]
# # Part 2: two plots
# In this part you are required to make one chart with two plots, one for the `GDP` and one for the `UNRATE`.
#
# This tie you are asked to make the API calls by yourself (you can inspire yourself from the previous part). You can keep the same start and end date, but the seriesID should be different (`GDP` and `UNRATE` respectivelly). The units also differs:
# - for `GPD` the units would be `pc1`
# - for `UNRATE` the units would be `lin`
#
# Once you have the data you should plot the inside the same chart. You'll use the same values for `X` and the `Y` values will differs for the two plots.
