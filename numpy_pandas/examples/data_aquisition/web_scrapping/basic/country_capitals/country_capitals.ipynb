# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
# The url of a lisst of country with capitals
# HINT: do not hesitate to look at the website using a browser to identify the pattern of the data you want to scrap
url = "https://scrapethissite.com/pages/simple/"

# %%
# Make a GET request to fetch the raw HTML content
html_content = requests.get(url)

# %%
# Parse the html content
soup = BeautifulSoup(html_content.text, "html.parser")
# soup.prettify()

# %%
# Create a dictionary to store the data
# The keys of the dictionary will be the countries
# The values of the dictionary will be the capitals, the population and the area in km2 of the country
# HINT: you can use the find_all method to find all the tags of a certain type

data = {}
for country in soup.find_all("div", class_="col-md-4 country"):
    country_name = country.find("h3").text.strip()
    country_infos = country.find("div", class_="country-info")
    capital = country_infos.find("span", class_="country-capital").text
    population = int(country.find("span", class_="country-population").text)
    area = float(country.find("span", class_="country-area").text)
    # check if the data is not empty
    if country_name == "" or country_name == "None" or capital == "" or capital == "None" or population == 0 or area == 0:
        continue
    data[country_name] = {"capital": capital, "population": population, "area": area}
# data = pd.DataFrame.from_dict(data)
data
# Out:
# {'Andorra': {'capital': 'Andorra la Vella',
#   'population': 84000,
#   'area': 468.0},
#  'United Arab Emirates': {'capital': 'Abu Dhabi',
#   'population': 4975593,
#   'area': 82880.0},
#  'Afghanistan': {'capital': 'Kabul', 'population': 29121286, 'area': 647500.0},
#  'Antigua and Barbuda': {'capital': "St. John's",
#   'population': 86754,
#   'area': 443.0},
#  'Anguilla': {'capital': 'The Valley', 'population': 13254, 'area': 102.0},
#  'Albania': {'capital': 'Tirana', 'population': 2986952, 'area': 28748.0},
#  'Armenia': {'capital': 'Yerevan', 'population': 2968000, 'area': 29800.0},
#  'Angola': {'capital': 'Luanda', 'population': 13068161, 'area': 1246700.0},
#  'Argentina': {'capital': 'Buenos Aires',
#   'population': 41343201,
#   'area': 2766890.0},
#  'American Samoa': {'capital': 'Pago Pago',
#   'population': 57881,
#   'area': 199.0},
#  'Austria': {'capital': 'Vienna', 'population': 8205000, 'area': 83858.0},
#  'Australia': {'capital': 'Canberra',
#   'population': 21515754,
#   'area': 7686850.0},
#  'Aruba': {'capital': 'Oranjestad', 'population': 71566, 'area': 193.0},
#  'Åland': {'capital': 'Mariehamn', 'population': 26711, 'area': 1580.0},
#  'Azerbaijan': {'capital': 'Baku', 'population': 8303512, 'area': 86600.0},
#  'Bosnia and Herzegovina': {'capital': 'Sarajevo',
#   'population': 4590000,
#   'area': 51129.0},
#  'Barbados': {'capital': 'Bridgetown', 'population': 285653, 'area': 431.0},
#  'Bangladesh': {'capital': 'Dhaka', 'population': 156118464, 'area': 144000.0},
#  'Belgium': {'capital': 'Brussels', 'population': 10403000, 'area': 30510.0},
#  'Burkina Faso': {'capital': 'Ouagadougou',
#   'population': 16241811,
#   'area': 274200.0},
#  'Bulgaria': {'capital': 'Sofia', 'population': 7148785, 'area': 110910.0},
#  'Bahrain': {'capital': 'Manama', 'population': 738004, 'area': 665.0},
#  'Burundi': {'capital': 'Bujumbura', 'population': 9863117, 'area': 27830.0},
#  'Benin': {'capital': 'Porto-Novo', 'population': 9056010, 'area': 112620.0},
#  'Saint Barthélemy': {'capital': 'Gustavia', 'population': 8450, 'area': 21.0},
#  'Bermuda': {'capital': 'Hamilton', 'population': 65365, 'area': 53.0},
#  'Brunei': {'capital': 'Bandar Seri Begawan',
#   'population': 395027,
#   'area': 5770.0},
#  'Bolivia': {'capital': 'Sucre', 'population': 9947418, 'area': 1098580.0},
#  'Bonaire': {'capital': 'Kralendijk', 'population': 18012, 'area': 328.0},
#  'Brazil': {'capital': 'Brasília', 'population': 201103330, 'area': 8511965.0},
#  'Bahamas': {'capital': 'Nassau', 'population': 301790, 'area': 13940.0},
#  'Bhutan': {'capital': 'Thimphu', 'population': 699847, 'area': 47000.0},
#  'Botswana': {'capital': 'Gaborone', 'population': 2029307, 'area': 600370.0},
#  'Belarus': {'capital': 'Minsk', 'population': 9685000, 'area': 207600.0},
#  'Belize': {'capital': 'Belmopan', 'population': 314522, 'area': 22966.0},
#  'Canada': {'capital': 'Ottawa', 'population': 33679000, 'area': 9984670.0},
#  'Cocos [Keeling] Islands': {'capital': 'West Island',
#   'population': 628,
#   'area': 14.0},
#  'Democratic Republic of the Congo': {'capital': 'Kinshasa',
#   'population': 70916439,
#   'area': 2345410.0},
#  'Central African Republic': {'capital': 'Bangui',
#   'population': 4844927,
#   'area': 622984.0},
#  'Republic of the Congo': {'capital': 'Brazzaville',
#   'population': 3039126,
#   'area': 342000.0},
#  'Switzerland': {'capital': 'Bern', 'population': 7581000, 'area': 41290.0},
#  'Ivory Coast': {'capital': 'Yamoussoukro',
#   'population': 21058798,
#   'area': 322460.0},
#  'Cook Islands': {'capital': 'Avarua', 'population': 21388, 'area': 240.0},
#  'Chile': {'capital': 'Santiago', 'population': 16746491, 'area': 756950.0},
#  'Cameroon': {'capital': 'Yaoundé', 'population': 19294149, 'area': 475440.0},
#  'China': {'capital': 'Beijing', 'population': 1330044000, 'area': 9596960.0},
#  'Colombia': {'capital': 'Bogotá', 'population': 47790000, 'area': 1138910.0},
#  'Costa Rica': {'capital': 'San José', 'population': 4516220, 'area': 51100.0},
#  'Cuba': {'capital': 'Havana', 'population': 11423000, 'area': 110860.0},
#  'Cape Verde': {'capital': 'Praia', 'population': 508659, 'area': 4033.0},
#  'Curacao': {'capital': 'Willemstad', 'population': 141766, 'area': 444.0},
#  'Christmas Island': {'capital': 'Flying Fish Cove',
#   'population': 1500,
#   'area': 135.0},
#  'Cyprus': {'capital': 'Nicosia', 'population': 1102677, 'area': 9250.0},
#  'Czech Republic': {'capital': 'Prague',
#   'population': 10476000,
#   'area': 78866.0},
#  'Germany': {'capital': 'Berlin', 'population': 81802257, 'area': 357021.0},
#  'Djibouti': {'capital': 'Djibouti', 'population': 740528, 'area': 23000.0},
#  'Denmark': {'capital': 'Copenhagen', 'population': 5484000, 'area': 43094.0},
#  'Dominica': {'capital': 'Roseau', 'population': 72813, 'area': 754.0},
#  'Dominican Republic': {'capital': 'Santo Domingo',
#   'population': 9823821,
#   'area': 48730.0},
#  'Algeria': {'capital': 'Algiers', 'population': 34586184, 'area': 2381740.0},
#  'Ecuador': {'capital': 'Quito', 'population': 14790608, 'area': 283560.0},
#  'Estonia': {'capital': 'Tallinn', 'population': 1291170, 'area': 45226.0},
#  'Egypt': {'capital': 'Cairo', 'population': 80471869, 'area': 1001450.0},
#  'Western Sahara': {'capital': 'Laâyoune / El Aaiún',
#   'population': 273008,
#   'area': 266000.0},
#  'Eritrea': {'capital': 'Asmara', 'population': 5792984, 'area': 121320.0},
#  'Spain': {'capital': 'Madrid', 'population': 46505963, 'area': 504782.0},
#  'Ethiopia': {'capital': 'Addis Ababa',
#   'population': 88013491,
#   'area': 1127127.0},
#  'Finland': {'capital': 'Helsinki', 'population': 5244000, 'area': 337030.0},
#  'Fiji': {'capital': 'Suva', 'population': 875983, 'area': 18270.0},
#  'Falkland Islands': {'capital': 'Stanley',
#   'population': 2638,
#   'area': 12173.0},
#  'Micronesia': {'capital': 'Palikir', 'population': 107708, 'area': 702.0},
#  'Faroe Islands': {'capital': 'Tórshavn', 'population': 48228, 'area': 1399.0},
#  'France': {'capital': 'Paris', 'population': 64768389, 'area': 547030.0},
#  'Gabon': {'capital': 'Libreville', 'population': 1545255, 'area': 267667.0},
#  'United Kingdom': {'capital': 'London',
#   'population': 62348447,
#   'area': 244820.0},
#  'Grenada': {'capital': "St. George's", 'population': 107818, 'area': 344.0},
#  'Georgia': {'capital': 'Tbilisi', 'population': 4630000, 'area': 69700.0},
#  'French Guiana': {'capital': 'Cayenne',
#   'population': 195506,
#   'area': 91000.0},
#  'Guernsey': {'capital': 'St Peter Port', 'population': 65228, 'area': 78.0},
#  'Ghana': {'capital': 'Accra', 'population': 24339838, 'area': 239460.0},
#  'Gibraltar': {'capital': 'Gibraltar', 'population': 27884, 'area': 6.5},
#  'Greenland': {'capital': 'Nuuk', 'population': 56375, 'area': 2166086.0},
#  'Gambia': {'capital': 'Bathurst', 'population': 1593256, 'area': 11300.0},
#  'Guinea': {'capital': 'Conakry', 'population': 10324025, 'area': 245857.0},
#  'Guadeloupe': {'capital': 'Basse-Terre',
#   'population': 443000,
#   'area': 1780.0},
#  'Equatorial Guinea': {'capital': 'Malabo',
#   'population': 1014999,
#   'area': 28051.0},
#  'Greece': {'capital': 'Athens', 'population': 11000000, 'area': 131940.0},
#  'South Georgia and the South Sandwich Islands': {'capital': 'Grytviken',
#   'population': 30,
#   'area': 3903.0},
#  'Guatemala': {'capital': 'Guatemala City',
#   'population': 13550440,
#   'area': 108890.0},
#  'Guam': {'capital': 'Hagåtña', 'population': 159358, 'area': 549.0},
#  'Guinea-Bissau': {'capital': 'Bissau',
#   'population': 1565126,
#   'area': 36120.0},
#  'Guyana': {'capital': 'Georgetown', 'population': 748486, 'area': 214970.0},
#  'Hong Kong': {'capital': 'Hong Kong', 'population': 6898686, 'area': 1092.0},
#  'Honduras': {'capital': 'Tegucigalpa',
#   'population': 7989415,
#   'area': 112090.0},
#  'Croatia': {'capital': 'Zagreb', 'population': 4491000, 'area': 56542.0},
#  'Haiti': {'capital': 'Port-au-Prince',
#   'population': 9648924,
#   'area': 27750.0},
#  'Hungary': {'capital': 'Budapest', 'population': 9982000, 'area': 93030.0},
#  'Indonesia': {'capital': 'Jakarta',
#   'population': 242968342,
#   'area': 1919440.0},
#  'Ireland': {'capital': 'Dublin', 'population': 4622917, 'area': 70280.0},
#  'Isle of Man': {'capital': 'Douglas', 'population': 75049, 'area': 572.0},
#  'India': {'capital': 'New Delhi',
#   'population': 1173108018,
#   'area': 3287590.0},
#  'Iraq': {'capital': 'Baghdad', 'population': 29671605, 'area': 437072.0},
#  'Iran': {'capital': 'Tehran', 'population': 76923300, 'area': 1648000.0},
#  'Iceland': {'capital': 'Reykjavik', 'population': 308910, 'area': 103000.0},
#  'Italy': {'capital': 'Rome', 'population': 60340328, 'area': 301230.0},
#  'Jersey': {'capital': 'Saint Helier', 'population': 90812, 'area': 116.0},
#  'Jamaica': {'capital': 'Kingston', 'population': 2847232, 'area': 10991.0},
#  'Jordan': {'capital': 'Amman', 'population': 6407085, 'area': 92300.0},
#  'Japan': {'capital': 'Tokyo', 'population': 127288000, 'area': 377835.0},
#  'Kenya': {'capital': 'Nairobi', 'population': 40046566, 'area': 582650.0},
#  'Kyrgyzstan': {'capital': 'Bishkek', 'population': 5776500, 'area': 198500.0},
#  'Cambodia': {'capital': 'Phnom Penh',
#   'population': 14453680,
#   'area': 181040.0},
#  'Kiribati': {'capital': 'Tarawa', 'population': 92533, 'area': 811.0},
#  'Comoros': {'capital': 'Moroni', 'population': 773407, 'area': 2170.0},
#  'Saint Kitts and Nevis': {'capital': 'Basseterre',
#   'population': 51134,
#   'area': 261.0},
#  'North Korea': {'capital': 'Pyongyang',
#   'population': 22912177,
#   'area': 120540.0},
#  'South Korea': {'capital': 'Seoul', 'population': 48422644, 'area': 98480.0},
#  'Kuwait': {'capital': 'Kuwait City', 'population': 2789132, 'area': 17820.0},
#  'Cayman Islands': {'capital': 'George Town',
#   'population': 44270,
#   'area': 262.0},
#  'Kazakhstan': {'capital': 'Astana',
#   'population': 15340000,
#   'area': 2717300.0},
#  'Laos': {'capital': 'Vientiane', 'population': 6368162, 'area': 236800.0},
#  'Lebanon': {'capital': 'Beirut', 'population': 4125247, 'area': 10400.0},
#  'Saint Lucia': {'capital': 'Castries', 'population': 160922, 'area': 616.0},
#  'Liechtenstein': {'capital': 'Vaduz', 'population': 35000, 'area': 160.0},
#  'Sri Lanka': {'capital': 'Colombo', 'population': 21513990, 'area': 65610.0},
#  'Liberia': {'capital': 'Monrovia', 'population': 3685076, 'area': 111370.0},
#  'Lesotho': {'capital': 'Maseru', 'population': 1919552, 'area': 30355.0},
#  'Lithuania': {'capital': 'Vilnius', 'population': 2944459, 'area': 65200.0},
#  'Luxembourg': {'capital': 'Luxembourg', 'population': 497538, 'area': 2586.0},
#  'Latvia': {'capital': 'Riga', 'population': 2217969, 'area': 64589.0},
#  'Libya': {'capital': 'Tripoli', 'population': 6461454, 'area': 1759540.0},
#  'Morocco': {'capital': 'Rabat', 'population': 31627428, 'area': 446550.0},
#  'Monaco': {'capital': 'Monaco', 'population': 32965, 'area': 1.95},
#  'Moldova': {'capital': 'Chişinău', 'population': 4324000, 'area': 33843.0},
#  'Montenegro': {'capital': 'Podgorica', 'population': 666730, 'area': 14026.0},
#  'Saint Martin': {'capital': 'Marigot', 'population': 35925, 'area': 53.0},
#  'Madagascar': {'capital': 'Antananarivo',
#   'population': 21281844,
#   'area': 587040.0},
#  'Marshall Islands': {'capital': 'Majuro', 'population': 65859, 'area': 181.3},
#  'Macedonia': {'capital': 'Skopje', 'population': 2062294, 'area': 25333.0},
#  'Mali': {'capital': 'Bamako', 'population': 13796354, 'area': 1240000.0},
#  'Myanmar [Burma]': {'capital': 'Naypyitaw',
#   'population': 53414374,
#   'area': 678500.0},
#  'Mongolia': {'capital': 'Ulan Bator',
#   'population': 3086918,
#   'area': 1565000.0},
#  'Macao': {'capital': 'Macao', 'population': 449198, 'area': 254.0},
#  'Northern Mariana Islands': {'capital': 'Saipan',
#   'population': 53883,
#   'area': 477.0},
#  'Martinique': {'capital': 'Fort-de-France',
#   'population': 432900,
#   'area': 1100.0},
#  'Mauritania': {'capital': 'Nouakchott',
#   'population': 3205060,
#   'area': 1030700.0},
#  'Montserrat': {'capital': 'Plymouth', 'population': 9341, 'area': 102.0},
#  'Malta': {'capital': 'Valletta', 'population': 403000, 'area': 316.0},
#  'Mauritius': {'capital': 'Port Louis', 'population': 1294104, 'area': 2040.0},
#  'Maldives': {'capital': 'Malé', 'population': 395650, 'area': 300.0},
#  'Malawi': {'capital': 'Lilongwe', 'population': 15447500, 'area': 118480.0},
#  'Mexico': {'capital': 'Mexico City',
#   'population': 112468855,
#   'area': 1972550.0},
#  'Malaysia': {'capital': 'Kuala Lumpur',
#   'population': 28274729,
#   'area': 329750.0},
#  'Mozambique': {'capital': 'Maputo', 'population': 22061451, 'area': 801590.0},
#  'Namibia': {'capital': 'Windhoek', 'population': 2128471, 'area': 825418.0},
#  'New Caledonia': {'capital': 'Noumea', 'population': 216494, 'area': 19060.0},
#  'Niger': {'capital': 'Niamey', 'population': 15878271, 'area': 1267000.0},
#  'Norfolk Island': {'capital': 'Kingston', 'population': 1828, 'area': 34.6},
#  'Nigeria': {'capital': 'Abuja', 'population': 154000000, 'area': 923768.0},
#  'Nicaragua': {'capital': 'Managua', 'population': 5995928, 'area': 129494.0},
#  'Netherlands': {'capital': 'Amsterdam',
#   'population': 16645000,
#   'area': 41526.0},
#  'Norway': {'capital': 'Oslo', 'population': 5009150, 'area': 324220.0},
#  'Nepal': {'capital': 'Kathmandu', 'population': 28951852, 'area': 140800.0},
#  'Nauru': {'capital': 'Yaren', 'population': 10065, 'area': 21.0},
#  'Niue': {'capital': 'Alofi', 'population': 2166, 'area': 260.0},
#  'New Zealand': {'capital': 'Wellington',
#   'population': 4252277,
#   'area': 268680.0},
#  'Oman': {'capital': 'Muscat', 'population': 2967717, 'area': 212460.0},
#  'Panama': {'capital': 'Panama City', 'population': 3410676, 'area': 78200.0},
#  'Peru': {'capital': 'Lima', 'population': 29907003, 'area': 1285220.0},
#  'French Polynesia': {'capital': 'Papeete',
#   'population': 270485,
#   'area': 4167.0},
#  'Papua New Guinea': {'capital': 'Port Moresby',
#   'population': 6064515,
#   'area': 462840.0},
#  'Philippines': {'capital': 'Manila',
#   'population': 99900177,
#   'area': 300000.0},
#  'Pakistan': {'capital': 'Islamabad',
#   'population': 184404791,
#   'area': 803940.0},
#  'Poland': {'capital': 'Warsaw', 'population': 38500000, 'area': 312685.0},
#  'Saint Pierre and Miquelon': {'capital': 'Saint-Pierre',
#   'population': 7012,
#   'area': 242.0},
#  'Pitcairn Islands': {'capital': 'Adamstown', 'population': 46, 'area': 47.0},
#  'Puerto Rico': {'capital': 'San Juan', 'population': 3916632, 'area': 9104.0},
#  'Portugal': {'capital': 'Lisbon', 'population': 10676000, 'area': 92391.0},
#  'Palau': {'capital': 'Melekeok', 'population': 19907, 'area': 458.0},
#  'Paraguay': {'capital': 'Asunción', 'population': 6375830, 'area': 406750.0},
#  'Qatar': {'capital': 'Doha', 'population': 840926, 'area': 11437.0},
#  'Réunion': {'capital': 'Saint-Denis', 'population': 776948, 'area': 2517.0},
#  'Romania': {'capital': 'Bucharest', 'population': 21959278, 'area': 237500.0},
#  'Serbia': {'capital': 'Belgrade', 'population': 7344847, 'area': 88361.0},
#  'Russia': {'capital': 'Moscow', 'population': 140702000, 'area': 17100000.0},
#  'Rwanda': {'capital': 'Kigali', 'population': 11055976, 'area': 26338.0},
#  'Saudi Arabia': {'capital': 'Riyadh',
#   'population': 25731776,
#   'area': 1960582.0},
#  'Solomon Islands': {'capital': 'Honiara',
#   'population': 559198,
#   'area': 28450.0},
#  'Seychelles': {'capital': 'Victoria', 'population': 88340, 'area': 455.0},
#  'Sudan': {'capital': 'Khartoum', 'population': 35000000, 'area': 1861484.0},
#  'Sweden': {'capital': 'Stockholm', 'population': 9828655, 'area': 449964.0},
#  'Singapore': {'capital': 'Singapore', 'population': 4701069, 'area': 692.7},
#  'Saint Helena': {'capital': 'Jamestown', 'population': 7460, 'area': 410.0},
#  'Slovenia': {'capital': 'Ljubljana', 'population': 2007000, 'area': 20273.0},
#  'Svalbard and Jan Mayen': {'capital': 'Longyearbyen',
#   'population': 2550,
#   'area': 62049.0},
#  'Slovakia': {'capital': 'Bratislava', 'population': 5455000, 'area': 48845.0},
#  'Sierra Leone': {'capital': 'Freetown',
#   'population': 5245695,
#   'area': 71740.0},
#  'San Marino': {'capital': 'San Marino', 'population': 31477, 'area': 61.2},
#  'Senegal': {'capital': 'Dakar', 'population': 12323252, 'area': 196190.0},
#  'Somalia': {'capital': 'Mogadishu', 'population': 10112453, 'area': 637657.0},
#  'Suriname': {'capital': 'Paramaribo', 'population': 492829, 'area': 163270.0},
#  'South Sudan': {'capital': 'Juba', 'population': 8260490, 'area': 644329.0},
#  'São Tomé and Príncipe': {'capital': 'São Tomé',
#   'population': 175808,
#   'area': 1001.0},
#  'El Salvador': {'capital': 'San Salvador',
#   'population': 6052064,
#   'area': 21040.0},
#  'Sint Maarten': {'capital': 'Philipsburg', 'population': 37429, 'area': 21.0},
#  'Syria': {'capital': 'Damascus', 'population': 22198110, 'area': 185180.0},
#  'Swaziland': {'capital': 'Mbabane', 'population': 1354051, 'area': 17363.0},
#  'Turks and Caicos Islands': {'capital': 'Cockburn Town',
#   'population': 20556,
#   'area': 430.0},
#  'Chad': {'capital': "N'Djamena", 'population': 10543464, 'area': 1284000.0},
#  'French Southern Territories': {'capital': 'Port-aux-Français',
#   'population': 140,
#   'area': 7829.0},
#  'Togo': {'capital': 'Lomé', 'population': 6587239, 'area': 56785.0},
#  'Thailand': {'capital': 'Bangkok', 'population': 67089500, 'area': 514000.0},
#  'Tajikistan': {'capital': 'Dushanbe',
#   'population': 7487489,
#   'area': 143100.0},
#  'East Timor': {'capital': 'Dili', 'population': 1154625, 'area': 15007.0},
#  'Turkmenistan': {'capital': 'Ashgabat',
#   'population': 4940916,
#   'area': 488100.0},
#  'Tunisia': {'capital': 'Tunis', 'population': 10589025, 'area': 163610.0},
#  'Tonga': {'capital': "Nuku'alofa", 'population': 122580, 'area': 748.0},
#  'Turkey': {'capital': 'Ankara', 'population': 77804122, 'area': 780580.0},
#  'Trinidad and Tobago': {'capital': 'Port of Spain',
#   'population': 1228691,
#   'area': 5128.0},
#  'Tuvalu': {'capital': 'Funafuti', 'population': 10472, 'area': 26.0},
#  'Taiwan': {'capital': 'Taipei', 'population': 22894384, 'area': 35980.0},
#  'Tanzania': {'capital': 'Dodoma', 'population': 41892895, 'area': 945087.0},
#  'Ukraine': {'capital': 'Kiev', 'population': 45415596, 'area': 603700.0},
#  'Uganda': {'capital': 'Kampala', 'population': 33398682, 'area': 236040.0},
#  'United States': {'capital': 'Washington',
#   'population': 310232863,
#   'area': 9629091.0},
#  'Uruguay': {'capital': 'Montevideo', 'population': 3477000, 'area': 176220.0},
#  'Uzbekistan': {'capital': 'Tashkent',
#   'population': 27865738,
#   'area': 447400.0},
#  'Vatican City': {'capital': 'Vatican City', 'population': 921, 'area': 0.44},
#  'Saint Vincent and the Grenadines': {'capital': 'Kingstown',
#   'population': 104217,
#   'area': 389.0},
#  'Venezuela': {'capital': 'Caracas', 'population': 27223228, 'area': 912050.0},
#  'British Virgin Islands': {'capital': 'Road Town',
#   'population': 21730,
#   'area': 153.0},
#  'U.S. Virgin Islands': {'capital': 'Charlotte Amalie',
#   'population': 108708,
#   'area': 352.0},
#  'Vietnam': {'capital': 'Hanoi', 'population': 89571130, 'area': 329560.0},
#  'Vanuatu': {'capital': 'Port Vila', 'population': 221552, 'area': 12200.0},
#  'Wallis and Futuna': {'capital': 'Mata-Utu',
#   'population': 16025,
#   'area': 274.0},
#  'Samoa': {'capital': 'Apia', 'population': 192001, 'area': 2944.0},
#  'Kosovo': {'capital': 'Pristina', 'population': 1800000, 'area': 10908.0},
#  'Yemen': {'capital': 'Sanaa', 'population': 23495361, 'area': 527970.0},
#  'Mayotte': {'capital': 'Mamoudzou', 'population': 159042, 'area': 374.0},
#  'South Africa': {'capital': 'Pretoria',
#   'population': 49000000,
#   'area': 1219912.0},
#  'Zambia': {'capital': 'Lusaka', 'population': 13460305, 'area': 752614.0},
#  'Zimbabwe': {'capital': 'Harare', 'population': 11651858, 'area': 390580.0}}

# %% [markdown]
# # Make some computation

# %%
# 1. Compute the total area of all the countries
total_area = sum(data[country]["area"] for country in data)
print(f"1.\tThe total area of all the countries is\t\t\t: {total_area} km2")

# 2. Compute the total population of all the countries
total_population = sum(data[country]["population"] for country in data)
print(f"2.\tThe total population of all the countries is\t\t: {total_population}")

# 3. Compute the total population density of all the countries
total_population_density = total_population / total_area
print(f"3.\tThe total population density of all the countries is\t: {total_population_density}")

# 4. Compute the average area of all the countries
average_area = total_area / len(data)
print(f"4.\tThe average area of all the countries is\t\t: {average_area} km2")

# 5. Compute the average population of all the countries
average_population = total_population / len(data)
print(f"5.\tThe average population of all the countries is\t\t: {average_population}")

# 6. Compute the average population density of all the countries
average_population_density = average_population / average_area
print(f"6.\tThe average population density of all the countries is\t: {average_population_density}")

# 7. Compute the country with the highest population
highest_population = max(data, key=lambda country: data[country]["population"])
print(f"7.\tThe country with the highest population is\t\t: {highest_population}")

# 8. Compute the country with the lowest population
lowest_population = min(data, key=lambda country: data[country]["population"])
print(f"8.\tThe country with the lowest population is\t\t: {lowest_population}")

# 9. Compute the country with the highest population density
highest_population_density = max(data, key=lambda country: data[country]["population"] / data[country]["area"])
print(f"9.\tThe country with the highest population density is\t: {highest_population_density}")

# 10. Compute the country with the lowest population density
lowest_population_density = min(data, key=lambda country: data[country]["population"] / data[country]["area"])
print(f"10.\tThe country with the lowest population density is\t: {lowest_population_density}")

# 11. Compute the country with the highest area
highest_area = max(data, key=lambda country: data[country]["area"])
print(f"11.\tThe country with the highest area is\t\t\t: {highest_area}")

# 12. Compute the country with the lowest area
lowest_area = min(data, key=lambda country: data[country]["area"])
print(f"12.\tThe country with the lowest area is\t\t\t: {lowest_area}")

# 13. Compute the country that have the longest capital name
longest_capital = ""
for country in data:
    if len(data[country]["capital"]) > len(longest_capital):
        longest_capital = data[country]["capital"]
print(f"13.\tThe country that have the longest capital name is\t: {longest_capital}")

# 14. Compute the country that have the shortest capital name
shortest_capital = ""
for country in data:
    if len(data[country]["capital"]) < len(shortest_capital) or shortest_capital == "":
        shortest_capital = data[country]["capital"]
print(f"14.\tThe country that have the shortest capital name is\t: {shortest_capital}")
# Out:
# 1.	The total area of all the countries is			: 135881958.69 km2
# 2.	The total population of all the countries is		: 6850259444
# 3.	The total population density of all the countries is	: 50.413311009360164
# 4.	The average area of all the countries is		: 561495.6970661157 km2
# 5.	The average population of all the countries is		: 28306857.20661157
# 6.	The average population density of all the countries is	: 50.413311009360164
# 7.	The country with the highest population is		: China
# 8.	The country with the lowest population is		: South Georgia and the South Sandwich Islands
# 9.	The country with the highest population density is	: Monaco
# 10.	The country with the lowest population density is	: South Georgia and the South Sandwich Islands
# 11.	The country with the highest area is			: Russia
# 12.	The country with the lowest area is			: Vatican City
# 13.	The country that have the longest capital name is	: Bandar Seri Begawan
# 14.	The country that have the shortest capital name is	: Baku
