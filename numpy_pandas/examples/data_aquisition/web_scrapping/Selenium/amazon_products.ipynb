# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
# import NoSuchElementException
from selenium.common.exceptions import NoSuchElementException
from time import sleep

# %%
# Path to chromedriver
PATH = "./webdrivers/chrome/chromedriver"
browser = webdriver.Chrome()

# %%
# load the webpage
browser.get('https://www.amazon.fr')

# %%
# get the input elements
input_search = browser.find_element(By.ID, 'twotabsearchtextbox')
search_button = browser.find_element(By.CSS_SELECTOR, '#nav-search-submit-button')
# search_button = browser.find_element(By.XPATH, "(//input[@type='submit'])[1]")

# %%
# send the input to the webpage
input_search.send_keys("Smartphones android 500 euro")
sleep(1)
search_button.click()

# %%
products = []
for i in range(5):
    print('Scraping page', i+1)
    # product = browser.find_elements(By.XPATH, "//span[@class='a-size-medium a-color-base a-text-normal']")
    product = browser.find_elements(By.XPATH, "//div[@class='sg-col-4-of-24 sg-col-4-of-12 s-result-item s-asin sg-col-4-of-16 sg-col s-widget-spacing-small sg-col-4-of-20']")
    for p in product:
        try:
          price = float(p.find_element(By.XPATH, ".//span[@class='a-price-whole']").text.strip().replace(',', '.'))
          decimal = float("0." + p.find_element(By.XPATH, ".//span[@class='a-price-fraction']").text.strip())
          final_price = price + decimal
        except:
          continue
        try:
          sponsored: bool = p.find_element(By.XPATH, ".//span[@class='puis-label-popover-default']")
        except:
          sponsored = False
           
        if final_price < 500 and not sponsored: 
            name = p.find_element(By.CSS_SELECTOR, ".a-text-normal").text
            products.append((name, final_price))
    next_button = browser.find_element(By.XPATH, "//a[text()='Suivant']")
    if next_button:
      next_button.click()
    sleep(2)
# Out:
# Scraping page 1
# 84.77
# 49.99
# 79.99
# 96.33
# 69.99
# 99.99
# 105.28
# 139.0
# 76.01
# 59.99
# 65.96
# 83.25
# 99.99
# 64.99
# 79.98
# 89.99
# 119.0
# 167.87
# 79.45
# 123.86
# 83.84
# 78.29
# 99.99
# 79.99
# 240.45
# 56.99
# 117.9
# 169.99
# 69.99
# 59.99
# 50.51
# 129.99
# 64.02
# 59.9
# 84.55
# 51.99
# 104.99
# 132.0
# 131.25
# 125.73
# 379.48
# 349.9
# 84.99
# 69.99
# 72.99
# Scraping page 2
# 99.99
# 118.38
# 115.99
# 79.9
# 119.99
# 399.0
# 199.02
# 100.91
# 98.99
# 299.99
# 89.99
# 72.97
# 66.82
# 119.99
# 58.99
# 169.99
# 144.33
# 51.99
# 129.99
# 100.51
# 160.0
# 60.99
# 64.99
# 128.4
# 59.99
# 170.91
# 219.89
# 179.99
# 39.25
# 70.31
# 120.79
# 84.99
# 189.99
# 759.0
# 203.63
# 59.99
# 59.99
# 58.62
# 9.77
# 90.79
# 58.99
# 169.99
# 72.71
# 104.99
# 129.99
# Scraping page 3
# 84.99
# 49.99
# 159.99
# 159.99
# 66.73
# 62.99
# 92.23
# 128.48
# 129.7
# 105.99
# 59.0
# 66.4
# 99.37
# 130.0
# 87.15
# 129.39
# 773.0
# 129.99
# 159.99
# 129.99
# 59.99
# 149.99
# 239.99
# 100.23
# 79.99
# 163.81
# 99.99
# 329.0
# 47.37
# 119.99
# 129.99
# 139.58
# 55.49
# 317.69
# 136.61
# 159.99
# 59.99
# 111.99
# 99.99
# 109.99
# Scraping page 4
# 188.51
# 259.9
# 221.39
# 100.29
# 117.18
# 45.0
# 99.99
# 83.3
# 149.9
# 239.0
# 114.79
# 129.99
# 107.53
# 116.54
# 199.99
# 79.99
# 152.05
# 42.58
# 94.99
# 64.39
# 149.99
# 79.9
# 115.3
# 254.29
# 138.99
# 67.89
# 209.55
# 121.99
# 149.99
# 125.56
# 119.0
# 65.45
# 109.99
# 159.99
# 81.19
# 84.48
# 195.0
# 122.89
# Scraping page 5
# 178.25
# 119.0
# 83.58
# 130.7
# 89.99
# 64.87
# 131.36
# 208.25
# 50.8
# 154.99
# 64.42
# 205.99
# 129.99
# 135.36
# 179.0
# 76.79
# 188.16
# 58.43
# 251.4
# 124.89
# 224.69
# 115.0
# 154.17
# 23.99
# 296.0
# 348.95
# 208.2
# 29.9
# 47.09
# 121.24
# 569.01
# 21.99
# 369.99
# 119.0
# 400.22
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[14], line 22
#      20         name = p.find_element(By.CSS_SELECTOR, ".a-text-normal").text
#      21         products.append((name, price))
# ---> 22 next_button = browser.find_element(By.XPATH, "//a[text()='Suivant']")
#      23 if next_button:
#      24   next_button.click()
#
# File ~/miniconda3/envs/nomades_nppd_env_310/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:741, in WebDriver.find_element(self, by, value)
#     738     by = By.CSS_SELECTOR
#     739     value = f'[name="{value}"]'
# --> 741 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~/miniconda3/envs/nomades_nppd_env_310/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
# --> 347     self.error_handler.check_response(response)
#     348     response["value"] = self._unwrap_value(response.get("value", None))
#     349     return response
#
# File ~/miniconda3/envs/nomades_nppd_env_310/lib/python3.10/site-packages/selenium/webdriver/remote/errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//a[text()='Suivant']"}
#   (Session info: chrome=121.0.6167.184); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 0   chromedriver                        0x0000000100df2814 chromedriver + 4040724
# 1   chromedriver                        0x0000000100deaa18 chromedriver + 4008472
# 2   chromedriver                        0x0000000100a5d870 chromedriver + 284784
# 3   chromedriver                        0x0000000100aa1080 chromedriver + 561280
# 4   chromedriver                        0x0000000100adb048 chromedriver + 798792
# 5   chromedriver                        0x0000000100a9574c chromedriver + 513868
# 6   chromedriver                        0x0000000100a96044 chromedriver + 516164
# 7   chromedriver                        0x0000000100db7a3c chromedriver + 3799612
# 8   chromedriver                        0x0000000100dbbf1c chromedriver + 3817244
# 9   chromedriver                        0x0000000100da0298 chromedriver + 3703448
# 10  chromedriver                        0x0000000100dbca64 chromedriver + 3820132
# 11  chromedriver                        0x0000000100d93054 chromedriver + 3649620
# 12  chromedriver                        0x0000000100dd9e74 chromedriver + 3939956
# 13  chromedriver                        0x0000000100dd9fec chromedriver + 3940332
# 14  chromedriver                        0x0000000100dea698 chromedriver + 4007576
# 15  libsystem_pthread.dylib             0x0000000182231034 _pthread_start + 136
# 16  libsystem_pthread.dylib             0x000000018222be3c thread_start + 8

# %%
len(products)
# Out:
# 205

# %%
products[:5]
# Out:
# [('Xiaomi Redmi 12C Smartphone 6,71 "HD+ Display 50MP Dual Camera MediaTek Helio G85 5000mAh Akku. (4+128, Ocean Blue) (3+64, Graphite Gray)',
#   84.0),
#  ('KXD Téléphone Portable Débloqué 6A Ecran 5.5 Pouces, Android 8.1, Smartphone Débloqué Pas Cher 3G Dual SIM, Caméra 5MP+2MP, 1Go RAM+8Go ROM, Batterie 2500mAh, Face ID, GPS - Noir',
#   49.0),
#  ('Blackview WAVE 6C Portable Débloqué Smartphone Écran 6,5"HD+/60Hz, 32Go+4Go/1To, 5100mAh/10W Charge Rapide, Android 13 Smartphone Pas Cher 4G Double SIM, Octa-Core/Face ID/OTG/GPS/2Ans Garantie-Violet',
#   79.0),
#  ('Xiaomi Redmi 10 (2022) - Smartphone 64GB, 4GB RAM, Dual Sim, Sea Blue',
#   96.0),
#  ('Ulefone Android 12 Téléphone Portable Note 15, 6,22" HD+ Smartphone Pas Cher, 32Go ROM+ 5Go RAM/TF-64Go, Double SIM Smartphone Débloqué/3 Slots/Face ID/WiFi/GPS/CTIA 3,5 mm/2Ans de Garantie- Noir',
#   69.0)]

# %%
browser.quit()
