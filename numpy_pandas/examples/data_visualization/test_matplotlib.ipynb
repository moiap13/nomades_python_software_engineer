# %%
import matplotlib.pyplot as plt

x = ["Jan", "FEB", "MAR", "APR"]
x1 = ["Jan", "FEB", "MAR", "APR"]
y = [10, 20, 30, 40]
y1 = [20, 30, 10, 80]

plt.plot(x, y, '')
plt.plot(x1, y1, '')
plt.legend(["2021", "2022"])
plt.show()
